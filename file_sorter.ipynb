# %%
import os, shutil
path = r"C:\Users\user\Documents\First File Sorting"
file_name = os.listdir(path)

# %%
path = path.replace('\\', '/') + '/'
print(path)
# Out:
# C:/Users/user/Documents/First File Sorting/

# %%
folder_names = ['csv files', 'image files', 'text files']

for folders in range(0,3):
    if not os.path.exists(path + folder_names[folders]):
        print(path + folder_names[folders])
        os.makedirs(path + folder_names[folders])
# Out:
# C:/Users/user/Documents/First File Sorting/csv files
# C:/Users/user/Documents/First File Sorting/image files
# C:/Users/user/Documents/First File Sorting/text files

# %%
for file in file_name:
    if '.csv' in file and not os.path.exists(path + 'csv files/' + file):
        shutil.move(path + file, path + 'csv files/' + file)
    elif '.png' in file and not os.path.exists(path + 'image files/' + file):
        shutil.move(path + file, path + 'image files/' + file)
    elif '.txt' in file and not os.path.exists(path + 'text files/' + file):
        shutil.move(path + file, path + 'text files/' + file)
